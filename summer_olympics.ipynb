# %%
import pandas as pd
import matplotlib as mpl

# %%
df=pd.read_csv("/content/summer.csv")

# %%
df
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# ...

# %% [markdown]
# ## **1. In how many cities Summer Olympics is held so far?**

# %%
print(len(df["City"].unique()),"Cities")
# Out:
# 22 Cities

# %% [markdown]
# ## **2. Which sport is having most number of Gold Medals so far? (Top 5)**

# %%
x=df[df["Medal"]=="Gold"]

# %%
x
# Out:
#        Year    City      Sport  ... Gender                       Event Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6      1896  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9      1896  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13     1896  Athens  Athletics  ...    Men                        100M  Gold
# ...     ...     ...        ...  ...    ...                         ...   ...
# 31145  2012  London  Wrestling  ...    Men                    Wg 60 KG  Gold
# 31149  2012  London  Wrestling  ...    Men                    Wg 66 KG  Gold
# 31153  2012  London  Wrestling  ...    Men                    Wg 74 KG  Gold
# 31157  2012  London  Wrestling  ...    Men                    Wg 84 KG  Gold
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG  Gold
#
# [10486 rows x 9 columns]

# %%
var=[]
for sport in x["Sport"].unique():
  var.append([sport,len(x[x["Sport"]==sport])])

# %%
var
# Out:
# [['Aquatics', 1421],
#  ['Athletics', 1215],
#  ['Cycling', 371],
#  ['Fencing', 552],
#  ['Gymnastics', 820],
#  ['Shooting', 384],
#  ['Tennis', 92],
#  ['Weightlifting', 200],
#  ['Wrestling', 391],
#  ['Archery', 126],
#  ['Basque Pelota', 2],
#  ['Cricket', 12],
#  ['Croquet', 4],
#  ['Equestrian', 320],
#  ['Football', 503],
#  ['Golf', 13],
#  ['Polo', 22],
#  ['Rowing', 890],
#  ['Rugby', 78],
#  ['Sailing', 412],
#  ['Tug of War', 36],
#  ['Boxing', 239],
#  ['Lacrosse', 28],
#  ['Roque', 1],
#  ['Hockey', 486],
#  ['Jeu de paume', 1],
#  ['Rackets', 3],
#  ['Skating', 9],
#  ['Water Motorsports', 5],
#  ['Modern Pentathlon', 60],
#  ['Ice Hockey', 8],
#  ['Basketball', 342],
#  ['Canoe / Kayak', 334],
#  ['Handball', 321],
#  ['Judo', 123],
#  ['Volleyball', 332],
#  ['Table Tennis', 46],
#  ['Badminton', 46],
#  ['Baseball', 111],
#  ['Softball', 60],
#  ['Taekwondo', 32],
#  ['Triathlon', 8],
#  ['Canoe', 27]]

# %%
len(var)
# Out:
# 43

# %%
pd.DataFrame(var,columns=["Sport","Freq"]).sort_values(by="Freq",ascending=False).head()
# Out:
#          Sport  Freq
# 0     Aquatics  1421
# 1    Athletics  1215
# 17      Rowing   890
# 4   Gymnastics   820
# 3      Fencing   552

# %%
print("Aquatics is having most number of gold medals that is 1421.")
# Out:
# Aquatics is having most number of gold medals that is 1421.

# %%
b=pd.DataFrame(var,columns=["Sport","Freq"]).sort_values(by="Freq",ascending=False).head().plot(x="Sport",y="Freq",kind="bar",figsize=(7.5,5))

# %% [markdown]
# ## **3. Which sport is having most number of medals so far? (Top 5)**

# %%
var=[]
for sport in df["Sport"].unique():
  var.append([sport,len(df[df["Sport"]==sport])])

# %%
var
# Out:
# [['Aquatics', 4170],
#  ['Athletics', 3638],
#  ['Cycling', 1105],
#  ['Fencing', 1613],
#  ['Gymnastics', 2307],
#  ['Shooting', 1150],
#  ['Tennis', 296],
#  ['Weightlifting', 593],
#  ['Wrestling', 1212],
#  ['Archery', 329],
#  ['Basque Pelota', 4],
#  ['Cricket', 24],
#  ['Croquet', 8],
#  ['Equestrian', 939],
#  ['Football', 1497],
#  ['Golf', 30],
#  ['Polo', 66],
#  ['Rowing', 2667],
#  ['Rugby', 192],
#  ['Sailing', 1109],
#  ['Tug of War', 94],
#  ['Boxing', 894],
#  ['Lacrosse', 59],
#  ['Roque', 3],
#  ['Hockey', 1422],
#  ['Jeu de paume', 3],
#  ['Rackets', 10],
#  ['Skating', 27],
#  ['Water Motorsports', 5],
#  ['Modern Pentathlon', 180],
#  ['Ice Hockey', 27],
#  ['Basketball', 1012],
#  ['Canoe / Kayak', 1002],
#  ['Handball', 973],
#  ['Judo', 491],
#  ['Volleyball', 994],
#  ['Table Tennis', 144],
#  ['Badminton', 144],
#  ['Baseball', 335],
#  ['Softball', 180],
#  ['Taekwondo', 112],
#  ['Triathlon', 24],
#  ['Canoe', 81]]

# %%
len(var)
# Out:
# 43

# %%
pd.DataFrame(var,columns=["Sport","Freq"]).sort_values(by="Freq",ascending=False).head()
# Out:
#          Sport  Freq
# 0     Aquatics  4170
# 1    Athletics  3638
# 17      Rowing  2667
# 4   Gymnastics  2307
# 3      Fencing  1613

# %%
print("Aquatics is having most number of medals that is 4170.")
# Out:
# Aquatics is having most number of medals that is 4170.

# %%
c=pd.DataFrame(var,columns=["Sport","Freq"]).sort_values(by="Freq",ascending=False).head().plot(x="Sport",y="Freq",kind="bar",figsize=(7.5,5))

# %% [markdown]
# ## **4. Which player has won most number of medals? (Top 5)**

# %%
df["Athlete"].unique()
# Out:
# array(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios', ...,
#        'TOTROV, Rustam', 'ALEKSANYAN, Artur', 'LIDBERG, Jimmy'],
#       dtype=object)

# %%
var=[]
for athlete in df["Athlete"].unique():
  var.append([athlete,len(df[df["Athlete"]==athlete])])

# %%
var
# Out:
# [['HAJOS, Alfred', 2],
#  ['HERSCHMANN, Otto', 2],
#  ['DRIVAS, Dimitrios', 1],
#  ['MALOKINIS, Ioannis', 1],
#  ['CHASAPIS, Spiridon', 1],
#  ['CHOROPHAS, Efstathios', 2],
#  ['ANDREOU, Joannis', 1],
#  ['NEUMANN, Paul', 1],
#  ['PEPANOS, Antonios', 1],
#  ['LANE, Francis', 1],
#  ['SZOKOLYI, Alajos', 1],
#  ['BURKE, Thomas', 2],
#  ['HOFMANN, Fritz', 4],
#  ['CURTIS, Thomas', 1],
#  ['GOULDING, Grantley', 1],
#  ['LERMUSIAUX, Albin', 1],
#  ['FLACK, Edwin', 3],
#  ['BLAKE, Arthur', 1],
#  ['GMELIN, Charles', 1],
#  ['JAMISON, Herbert', 1],
#  ['GOLEMIS, Dimitrios', 1],
#  ['DANI, Nandor', 1],
#  ['VERSIS, Sotirios', 2],
#  ['GARRETT, Robert', 6],
#  ['PARASKEVOPOULOS, Panagiotis', 1],
#  ['CLARK, Ellery', 2],
#  ['CONNOLLY, James', 5],
#  ['KELLNER, Gyula', 1],
#  ['LOUIS, Spyridon', 1],
#  ['VASILAKOS, Kharilaos', 1],
#  ['DAMASKOS, Evangelos', 1],
#  ['THEODOROPOULOS, Ioannis', 1],
#  ['HOYT, William Welles', 1],
#  ['TYLER, Albert', 1],
#  ['PAPASIDERIS, Georgios', 1],
# ...

# %%
len(var)
# Out:
# 22762

# %%
pd.DataFrame(var,columns=["Athlete","Medals"]).sort_values(by="Medals",ascending=False).head()
# Out:
#                     Athlete  Medals
# 18640       PHELPS, Michael      22
# 7197       LATYNINA, Larisa      18
# 9948     ANDRIANOV, Nikolay      15
# 6591           ONO, Takashi      13
# 5103   MANGIAROTTI, Edoardo      13

# %%
print("Michael Phelps has won most number of medals that is 22.")
# Out:
# Michael Phelps has won most number of medals that is 22.

# %%
d=pd.DataFrame(var,columns=["Athlete","Medals"]).sort_values(by="Medals",ascending=False).head().plot(x="Athlete",y="Medals",kind="bar",figsize=(7.5,5))

# %% [markdown]
# ## **5. Which player has won most number Gold Medals of medals? (Top 5)**

# %%
x
# Out:
#        Year    City      Sport  ... Gender                       Event Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6      1896  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9      1896  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13     1896  Athens  Athletics  ...    Men                        100M  Gold
# ...     ...     ...        ...  ...    ...                         ...   ...
# 31145  2012  London  Wrestling  ...    Men                    Wg 60 KG  Gold
# 31149  2012  London  Wrestling  ...    Men                    Wg 66 KG  Gold
# 31153  2012  London  Wrestling  ...    Men                    Wg 74 KG  Gold
# 31157  2012  London  Wrestling  ...    Men                    Wg 84 KG  Gold
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG  Gold
#
# [10486 rows x 9 columns]

# %%
var=[]
for athlete in x["Athlete"].unique():
  var.append([athlete,len(x[x["Athlete"]==athlete])])

# %%
var
# Out:
# [['HAJOS, Alfred', 2],
#  ['MALOKINIS, Ioannis', 1],
#  ['NEUMANN, Paul', 1],
#  ['BURKE, Thomas', 2],
#  ['CURTIS, Thomas', 1],
#  ['FLACK, Edwin', 2],
#  ['GARRETT, Robert', 2],
#  ['CLARK, Ellery', 2],
#  ['LOUIS, Spyridon', 1],
#  ['HOYT, William Welles', 1],
#  ['CONNOLLY, James', 1],
#  ['KONSTANTINIDIS, Aristidis', 1],
#  ['FLAMENG, Léon', 1],
#  ['MASSON, Paul', 3],
#  ['SCHMAL, Adolf', 1],
#  ['GRAVELOTTE, Eugène-Henri', 1],
#  ['PYRGOS, Leonidas', 1],
#  ['GEORGIADIS, Ioannis', 1],
#  ['WEINGÄRTNER, Hermann', 3],
#  ['FLATOW, Alfred', 3],
#  ['ZUTTER, Louis', 1],
#  ['MITROPOULOS, Ioannis', 1],
#  ['ANDRIAKOPOULOS, Nicolaos', 1],
#  ['BÖCKER, Konrad', 2],
#  ['FLATOW, Gustav Felix', 2],
#  ['HILMAR, Georg', 2],
#  ['HOFMANN, Fritz', 2],
#  ['MANTEUFFEL, Fritz', 2],
#  ['NEUKIRCH, Karl', 2],
#  ['RÖSTEL, Richard', 2],
#  ['SCHUFT, Gustav', 2],
#  ['SCHUMANN, Carl', 4],
#  ['PAINE, John', 1],
#  ['PHRANGOUDIS, Joannis', 1],
#  ['PAINE, Sumner', 1],
# ...

# %%
pd.DataFrame(var,columns=["Athlete","Gold Medals"]).sort_values(by="Gold Medals",ascending=False).head()
# Out:
#                Athlete  Gold Medals
# 6851   PHELPS, Michael           18
# 3320       SPITZ, Mark            9
# 2714  LATYNINA, Larisa            9
# 4630       LEWIS, Carl            9
# 907       NURMI, Paavo            9

# %%
print("Michael Phelps has won most number of gold medals that is 18.")
# Out:
# Michael Phelps has won most number of gold medals that is 18.

# %%
d=pd.DataFrame(var,columns=["Athlete","Gold Medals"]).sort_values(by="Gold Medals",ascending=False).head().plot(x="Athlete",y="Gold Medals",kind="bar",figsize=(7.5,5))

# %% [markdown]
# ## **6. In which year India won first Gold Medal in Summer Olympics?**

# %%
y=x[x["Country"]=="IND"]

# %%
y
# Out:
#        Year       City     Sport  ... Gender                     Event Medal
# 5512   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5513   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5514   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5515   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5516   1928  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# ...     ...        ...       ...  ...    ...                       ...   ...
# 16099  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16100  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16101  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16102  1980     Moscow    Hockey  ...    Men                    Hockey  Gold
# 28856  2008    Beijing  Shooting  ...    Men  10M Air Rifle (60 Shots)  Gold
#
# [128 rows x 9 columns]

# %%
var=[]
for year in df["Year"].unique():
  var.append([year,len(y[y["Year"]==year])])

# %%
var
# Out:
# [[1896, 0],
#  [1900, 0],
#  [1904, 0],
#  [1908, 0],
#  [1912, 0],
#  [1920, 0],
#  [1924, 0],
#  [1928, 15],
#  [1932, 11],
#  [1936, 19],
#  [1948, 20],
#  [1952, 14],
#  [1956, 17],
#  [1960, 0],
#  [1964, 15],
#  [1968, 0],
#  [1972, 0],
#  [1976, 0],
#  [1980, 16],
#  [1984, 0],
#  [1988, 0],
#  [1992, 0],
#  [1996, 0],
#  [2000, 0],
#  [2004, 0],
#  [2008, 1],
#  [2012, 0]]

# %%
for j in var:
  if j[1]>0:
    print(f"India got its first gold medal in {j[0]}.")  
    break
# Out:
# India got its first gold medal in 1928.

# %% [markdown]
# ## **7. Which event is most popular in terms on number of players? (Top 5)**

# %%
var=[]
for event in df["Event"].unique():
  var.append([event,len(df[df["Event"]==event])])

# %%
var
# Out:
# [['100M Freestyle', 148],
#  ['100M Freestyle For Sailors', 3],
#  ['1200M Freestyle', 3],
#  ['400M Freestyle', 144],
#  ['100M', 142],
#  ['110M Hurdles', 80],
#  ['1500M', 114],
#  ['400M', 119],
#  ['800M', 126],
#  ['Discus Throw', 141],
#  ['High Jump', 151],
#  ['Long Jump', 132],
#  ['Marathon', 105],
#  ['Pole Vault', 100],
#  ['Shot Put', 132],
#  ['Triple Jump', 96],
#  ['Individual Road Race', 76],
#  ['100KM', 5],
#  ['10KM', 9],
#  ['12-Hour Race', 2],
#  ['1KM Time Trial', 57],
#  ['Sprint Indivual', 69],
#  ['Foil Individual', 141],
#  ['Foil, Masters', 5],
#  ['Sabre Individual', 90],
#  ['Horizontal Bar', 72],
#  ['Parallel Bars', 72],
#  ['Pommel Horse', 69],
#  ['Rings', 73],
#  ['Rope Climbing', 13],
#  ['Team, Horizontal Bar', 11],
#  ['Team, Parallel Bars', 19],
#  ['Vault', 123],
#  ['25M Army Pistol', 3],
#  ['25M Rapid Fire Pistol (60 Shots)', 69],
#  ['50M Pistol (60 Shots)', 66],
#  ['Army Rifle, 200M', 3],
#  ['Army Rifle, 300M', 3],
#  ['Doubles', 318],
# ...

# %%
len(var)
# Out:
# 666

# %%
pd.DataFrame(var,columns=["Event","Number of players"]).sort_values(by="Number of players",ascending=False).head()
# Out:
#                 Event  Number of players
# 80           Football               1497
# 176            Hockey               1422
# 138  Team Competition               1147
# 327        Basketball               1012
# 337          Handball                973

# %%
print("Football event is most popular in terms of number of players having 1497 players.")
# Out:
# Football event is most popular in terms of number of players having 1497 players.

# %%
f=pd.DataFrame(var,columns=["Event","Number of players"]).sort_values(by="Number of players",ascending=False).head().plot(x="Event",y="Number of players",kind="bar",figsize=(7.5,5))

# %% [markdown]
# ## **8. Which sport is having most female Gold Medalists? (Top 5)**

# %%
x
# Out:
#        Year    City      Sport  ... Gender                       Event Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6      1896  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9      1896  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13     1896  Athens  Athletics  ...    Men                        100M  Gold
# ...     ...     ...        ...  ...    ...                         ...   ...
# 31145  2012  London  Wrestling  ...    Men                    Wg 60 KG  Gold
# 31149  2012  London  Wrestling  ...    Men                    Wg 66 KG  Gold
# 31153  2012  London  Wrestling  ...    Men                    Wg 74 KG  Gold
# 31157  2012  London  Wrestling  ...    Men                    Wg 84 KG  Gold
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG  Gold
#
# [10486 rows x 9 columns]

# %%
z=x[x["Gender"]=="Women"]

# %%
z
# Out:
#        Year      City  ...                                    Event Medal
# 417    1900     Paris  ...                               Individual  Gold
# 641    1900     Paris  ...                            Mixed Doubles  Gold
# 649    1900     Paris  ...                                  Singles  Gold
# 710    1904  St Louis  ...  Double Columbia Round (50Y - 40Y - 30Y)  Gold
# 713    1904  St Louis  ...        Double National Round (60Y - 50Y)  Gold
# ...     ...       ...  ...                                      ...   ...
# 31081  2012    London  ...                                     75KG  Gold
# 31097  2012    London  ...                                 Wf 48 KG  Gold
# 31105  2012    London  ...                                 Wf 55 KG  Gold
# 31113  2012    London  ...                                 Wf 63 KG  Gold
# 31121  2012    London  ...                                 Wf 72 KG  Gold
#
# [2788 rows x 9 columns]

# %%
var=[]
for sport in df["Sport"].unique():
  var.append([sport,len(z[z["Sport"]==sport])])

# %%
var
# Out:
# [['Aquatics', 589],
#  ['Athletics', 389],
#  ['Cycling', 45],
#  ['Fencing', 108],
#  ['Gymnastics', 268],
#  ['Shooting', 43],
#  ['Tennis', 38],
#  ['Weightlifting', 28],
#  ['Wrestling', 12],
#  ['Archery', 39],
#  ['Basque Pelota', 0],
#  ['Cricket', 0],
#  ['Croquet', 0],
#  ['Equestrian', 51],
#  ['Football', 86],
#  ['Golf', 1],
#  ['Polo', 0],
#  ['Rowing', 217],
#  ['Rugby', 0],
#  ['Sailing', 38],
#  ['Tug of War', 0],
#  ['Boxing', 3],
#  ['Lacrosse', 0],
#  ['Roque', 0],
#  ['Hockey', 144],
#  ['Jeu de paume', 0],
#  ['Rackets', 0],
#  ['Skating', 4],
#  ['Water Motorsports', 0],
#  ['Modern Pentathlon', 4],
#  ['Ice Hockey', 0],
#  ['Basketball', 120],
#  ['Canoe / Kayak', 76],
#  ['Handball', 142],
#  ['Judo', 42],
#  ['Volleyball', 166],
#  ['Table Tennis', 23],
#  ['Badminton', 23],
#  ['Baseball', 0],
#  ['Softball', 60],
#  ['Taekwondo', 16],
#  ['Triathlon', 4],
#  ['Canoe', 9]]

# %%
pd.DataFrame(var,columns=["Sport","Number of female gold medalists"]).sort_values(by="Number of female gold medalists",ascending=False).head()
# Out:
#          Sport  Number of female gold medalists
# 0     Aquatics                              589
# 1    Athletics                              389
# 4   Gymnastics                              268
# 17      Rowing                              217
# 35  Volleyball                              166

# %%
print("Aquatics is having most female gold medalists with number 589.")
# Out:
# Aquatics is having most female gold medalists with number 589.

# %%
g=pd.DataFrame(var,columns=["Sport","Number of female gold medalists"]).sort_values(by="Number of female gold medalists",ascending=False).head().plot(x="Sport",y="Number of female gold medalists",kind="bar",figsize=(7.5,5))
